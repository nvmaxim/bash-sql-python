# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
# УПРАЖНЕНИЕ 5: "Комплексный отчет" (python)
# Создайте комплексный отчет по отделам: количество менеджеров, общая выручка, доля в общей выручке, средняя выручка на менеджера и флаг высокой эффективности.

import sys
import pandas as pd
import numpy as np
import logging
from _001_main import df_csv

sys.setrecursionlimit(2000)


def get_complex_report(df: pd.DataFrame) -> pd.DataFrame:
    report = df.groupby("department").agg(
        manager_count=["manager", "count"], total_revenue=["revenue", "sum"]
    )

    total_reveneu_all =
    
    df["revenue_share"] = df["total_revenue"] / df["total_revenue"].sum()

    df["avg_per_manager"] = df["total_revenue"] / df["manager_count"]

    df["high_perfomance_flag"] = np.where(df["avg_per_manager"] >= 15000, "Yes", "No")

    pass


def solve(df: pd.DataFrame) -> None:
    if df.empty:
        sys.stdout.write(f"Error\n")
    try:
        result = get_complex_report(df).sort_values("total_revenue", ascending=False).
            if not analysis_result.empty:
            sys.stdout.write("Отчет по эффективности отделов:\n")
            sys.stdout.write(analysis_result.to_string(index=False) + "\n")
            
            # Дополнительный вывод победителя
            winner = analysis_result.iloc[0]['department']
            sys.stdout.write(f"\nЛидер по выручке: Отдел {winner}\n")
            
    except Exception as e:
        sys.stderr.write(f"Ошибка при обработке данных: {e}\n")

    pass


def main() -> None:
    try:
        df = df_csv.copy()
        solve(df)
    except EOFError:
        pass
    except Exception as e:
        sys.stdout.write(f"Error{e}\n")
    pass


if __name__ == "__main__":
    main()
