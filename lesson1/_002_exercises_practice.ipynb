# %%
from _001_main import df_csv

df = df_csv

print(df)
# Out:
#   manager department  revenue  experience period
# 0    Иван          А    15000           2     Q1
# 1   Мария          Б    22000           5     Q1
# 2    Петр          А    17000           3     Q1
# 3    Анна          В    12000           1     Q1
# 4  Сергей          Б    25000           4     Q1
# 5    Иван          А    18000           2     Q2
# 6   Мария          Б    19000           5     Q2
# 7    Анна          В    14000           1     Q2
# 8   Ольга          А    16000           2     Q2

# %%
import numpy as np

df_copy = df.copy()

df_copy["classification"] = np.where(
    df_copy["revenue"] >= 20000,
    "VIP",
    np.where(df_copy["revenue"] >= 15000, "Standart", "Basic"),
)

df_copy = df_copy[df_copy["classification"] == "VIP"].sort_values(
    "revenue", ascending=False
)


print(df_copy)
# Out:
#   manager department  revenue  experience period classification
# 4  Сергей          Б    25000           4     Q1            VIP
# 1   Мария          Б    22000           5     Q1            VIP
